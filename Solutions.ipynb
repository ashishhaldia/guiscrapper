# %% [markdown]
# ### Jupyter Notebook
# ### show them the solution
# ### what are they going to learn today
# ### probability spend some time
# ### question of 5 sunday in a 31 day month
# ### example of gf

# %% [markdown]
# ### probability question
#
# ![image.png](attachment:eadfa843-0525-41e0-86f0-5ed521fa6cc4.png)

# %% [markdown]
# ### Childeren Question
# ![image.png](attachment:730c3943-30a1-4981-9f82-d12fc8972722.png)

# %% [markdown]
# ### DICE Question
# ![image.png](attachment:3e0b5d80-f082-454c-befb-133cda285b14.png)

# %% [markdown]
# ### Urn Question
# ![image.png](attachment:065bdcf0-f072-4fe6-87e4-179befef9f03.png)

# %% [markdown]
# # Z value
# ![image.png](attachment:b327e8f7-c01c-4df0-b720-1249e2000067.png)
